# %%
import numpy as np
import scipy
import matplotlib
import pandas as pd
from numpy import genfromtxt
import json
import sys
import pandas
import matplotlib.pyplot as plt
import os

# %%
# %matplotlib inline

# %%
# os.environ["PATH"] += os.pathsep + '/usr/local/texlive/2019/bin/x86_64-darwin'
print(os.getenv("PATH"))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/opt/X11/bin:/Library/Frameworks/Python.framework/Versions/3.6/bin:/Users/mikhailgasanov/bin:/Users/mikhailgasanov/anaconda3/bin:/Users/mikhailgasanov/anaconda3/condabin:/usr/local/texlive/2019/bin/x86_64-darwin:/usr/local/texlive/2019/bin/x86_64-darwin

# %%
lgndsize = 'large'
fontsize = 'xx-large'
params = {'text.usetex': True,
          'text.latex.preamble': [ # to conform with acmart style
              r'\usepackage[T1]{fontenc}',
              r'\usepackage[libertine]{newtxmath}',
              r'\usepackage{libertine}'
          ],
          'font.weight': 'regular',
          'legend.fontsize': lgndsize,         
          'axes.labelsize': fontsize,
          'axes.titlesize': fontsize,
          'xtick.labelsize': lgndsize,
          'ytick.labelsize': lgndsize,
         }

plt.style.use(['seaborn-whitegrid']) # see plt.style.available
plt.rcParams.update(params)

# %%
plt.style.available
# Out:
# ['seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-ticks',
#  'fivethirtyeight',
#  'seaborn-whitegrid',
#  'classic',
#  '_classic_test',
#  'fast',
#  'seaborn-talk',
#  'seaborn-dark-palette',
#  'seaborn-bright',
#  'seaborn-pastel',
#  'grayscale',
#  'seaborn-notebook',
#  'ggplot',
#  'seaborn-colorblind',
#  'seaborn-muted',
#  'seaborn',
#  'Solarize_Light2',
#  'seaborn-paper',
#  'bmh',
#  'tableau-colorblind10',
#  'seaborn-white',
#  'dark_background',
#  'seaborn-poster',
#  'seaborn-deep']

# %%
names_for_legend=('sugar-beet-2011', 'spring-barley', 'sugar-beet-2014',
       'soybean', 'sugar-beet-2017')

# %%
csv_list_horisonts =['Si_BD_Hor.csv', 'Si_Clay_Hor.csv',\
          'Si_CN_Hor.csv', 'Si_pH_Hor.csv', 'Si_Sand_Hor.csv','Si_SOC_Hor.csv']

# %%
csv_list_horisonts_ST =['ST_BD_Hor.csv', 'ST_Clay_Hor.csv',\
          'ST_CN_Hor.csv', 'ST_pH_Hor.csv', 'ST_Sand_Hor.csv','ST_SOC_Hor.csv']

# %%
csv_list_horisonts[5]
# Out:
# 'Si_SOC_Hor.csv'

# %%
df_ST=pd.read_csv(csv_list_horisonts_ST[0])

# %%
S1_horiz_Bulk_density= np.genfromtxt(csv_list_horisonts_ST[0], delimiter=',', skip_header=1)
S1_horiz_Clay= np.genfromtxt(csv_list_horisonts_ST[1], delimiter=',', skip_header=1)
S1_horiz_CN= np.genfromtxt(csv_list_horisonts_ST[2], delimiter=',', skip_header=1)
S1_horiz_pH= np.genfromtxt(csv_list_horisonts_ST[3], delimiter=',', skip_header=1)
S1_horiz_Sand= np.genfromtxt(csv_list_horisonts_ST[4], delimiter=',', skip_header=1)
S1_horiz_SOC= np.genfromtxt(csv_list_horisonts_ST[5], delimiter=',', skip_header=1)

# %%
print(skala_depth)
# Out:
# (0, 40, 50, 60, 70, 80, 90, 100, 200)

# %%
fig, ((ax1, ax2, ax3),(ax4, ax5, ax6)) = plt.subplots(2,3)
ax1.set_ylabel('Depth, $cm$')
ax1.set_xlabel('Sand')
ax1.plot(S1_horiz_Sand[:,1], skala_depth)
ax1.plot(S1_horiz_Sand[:,3], skala_depth)
ax1.plot(S1_horiz_Sand[:,3], skala_depth)
ax1.plot(S1_horiz_Sand[:,4], skala_depth)
ax1.plot(S1_horiz_Sand[:,5], skala_depth)
# ax1.legend(names_for_legend)
ax1.xaxis.tick_top()
ax1.invert_yaxis()
# ax1.xaxis.set_major_formatter(plt.NullFormatter())
# ax1.yaxis.set_major_formatter(plt.NullFormatter())


ax2.set_xlabel('Clay')
ax2.plot(S1_horiz_Clay[:,1], skala_depth)
ax2.plot(S1_horiz_Clay[:,3], skala_depth)
ax2.plot(S1_horiz_Clay[:,3], skala_depth)
ax2.plot(S1_horiz_Clay[:,4], skala_depth)
ax2.plot(S1_horiz_Clay[:,5], skala_depth)
# ax2.legend(names_for_legend)
ax2.xaxis.tick_top()
ax2.invert_yaxis()
# ax2.xaxis.set_major_formatter(plt.NullFormatter())
ax2.yaxis.set_major_formatter(plt.NullFormatter())
ax3.set_xlabel('Bulk Density')
ax3.plot(S1_horiz_Bulk_density[:,1], skala_depth)
ax3.plot(S1_horiz_Bulk_density[:,3], skala_depth)
ax3.plot(S1_horiz_Bulk_density[:,3], skala_depth)
ax3.plot(S1_horiz_Bulk_density[:,4], skala_depth)
ax3.plot(S1_horiz_Bulk_density[:,5], skala_depth)
ax3.set_xlim(0,1,0.5)
# ax3.legend(names_for_legend)
ax3.xaxis.tick_top()
ax3.invert_yaxis()
# ax3.xaxis.set_major_formatter(plt.NullFormatter())
ax3.yaxis.set_major_formatter(plt.NullFormatter())
ax4.set_xlabel('C:N ratio')
ax4.set_ylabel('Depth, $cm$')
ax4.plot(S1_horiz_CN[:,1], skala_depth)
ax4.plot(S1_horiz_CN[:,3], skala_depth)
ax4.plot(S1_horiz_CN[:,3], skala_depth)
ax4.plot(S1_horiz_CN[:,4], skala_depth)
ax4.plot(S1_horiz_CN[:,5], skala_depth)
# ax4.legend(names_for_legend)
ax4.xaxis.tick_top()
ax4.invert_yaxis()
ax4.xaxis.set_major_formatter(plt.NullFormatter())
# ax4.yaxis.set_major_formatter(plt.NullFormatter())

ax5.set_xlabel('SOC')
ax5.plot(S1_horiz_SOC[:,1], skala_depth)
ax5.plot(S1_horiz_SOC[:,3], skala_depth)
ax5.plot(S1_horiz_SOC[:,3], skala_depth)
ax5.plot(S1_horiz_SOC[:,4], skala_depth)
ax5.plot(S1_horiz_SOC[:,5], skala_depth)
# ax5.legend(names_for_legend)
ax5.xaxis.set_major_formatter(plt.NullFormatter())
ax5.yaxis.set_major_formatter(plt.NullFormatter())

ax5.xaxis.tick_top()
ax5.invert_yaxis()

ax6.set_xlabel('pH')
ax6.plot(S1_horiz_pH[:,1], skala_depth)
ax6.plot(S1_horiz_pH[:,3], skala_depth)
ax6.plot(S1_horiz_pH[:,3], skala_depth)
ax6.plot(S1_horiz_pH[:,4], skala_depth)
ax6.plot(S1_horiz_pH[:,5], skala_depth)

ax6.xaxis.set_major_formatter(plt.NullFormatter())
ax6.yaxis.set_major_formatter(plt.NullFormatter())


ax6.legend(names_for_legend,bbox_to_anchor=(0.5, 0.3, 0.5, 0.5))
ax6.xaxis.tick_top()
ax6.invert_yaxis()

# fig.set_('Depth, $cm$')
fig.set_figheight(8)
fig.set_figwidth(10)
fig.suptitle('Sobol\' ST index for soil parameters', fontsize=22)
# fig.suptitle('Si index for soil parameters', va='center')
fig.suptitle
plt.savefig('Sobol_ST_horisonts_sns_white.png', dpi=400)
# fig.legend(names_for_legend, loc='upper right', borderaxespad=0.)
# fig.axes.get_xaxis().set_ticks([])
# fig.axes.get_yaxis().set_ticks([])
# for ax in fig.get_axes():
#     ax.set(xlabel='x-label', ylabel='y-label')

# %%
# !pwd
# Out:
# /Users/mikhailgasanov/MONICA/SA_horizonts

# %%
fig, (ax1, ax2) = plt.subplots(
    nrows=1, ncols=2,
    figsize=(8, 5)
)
ax1.set_ylabel('Soil profile, $cm$')
ax1.set_xlabel('First Sobol index')
ax1.plot(S1_horiz_Sand[:,1], S1_horiz_Sand[:,0])
ax1.plot(S1_horiz_Sand[:,2], S1_horiz_Sand[:,0])
ax1.plot(S1_horiz_Sand[:,3], S1_horiz_Sand[:,0])
ax1.plot(S1_horiz_Sand[:,4], S1_horiz_Sand[:,0])
ax1.plot(S1_horiz_Sand[:,5], S1_horiz_Sand[:,0])
ax1.set_title('Sand')
ax1.get_title()
ax1.invert_yaxis()
ax1.legend(names_for_legend)
ax1.xaxis.tick_top()

ax2.set_ylabel('Soil profile, $cm$')
ax2.set_xlabel('First Sobol index')
# ax2.yxticks(xi, for_yaxis_names)
# ax2.set_yticks([200,40,30]) 
# ax2.set_yticklabels([200,40,30], fontsize=12)
ax2.plot(S1_horiz_Clay[:,1], S1_horiz_Clay[:,0])
ax2.plot(S1_horiz_Clay[:,2], S1_horiz_Clay[:,0])
ax2.plot(S1_horiz_Clay[:,3], S1_horiz_Clay[:,0])
ax2.plot(S1_horiz_Clay[:,4], S1_horiz_Clay[:,0])
ax2.plot(S1_horiz_Clay[:,5], S1_horiz_Clay[:,0])
ax2.invert_yaxis()
ax2.set_title('Clay')
ax2.get_title()
# ax2.annotate('Clay', xy=[0.65,125])
ax2.legend(names_for_legend)
ax2.xaxis.tick_top()
ax2.yaxis.tick_right()

# plt.sca(ax2)
# plt.yticks(xi, for_yaxis_names)
# plt.savefig('local_macos1.png', dpi=400)

# %%
skala_depth=(0,40,50,60,70,80,90,100,200)

# %%
# !pwd
# Out:
# /Users/mikhailgasanov/MONICA/SA_horizonts

# %%
fig, (ax1, ax2) = plt.subplots(
    nrows=1, ncols=2,
    figsize=(8, 5)
)
ax1.set_ylabel('Depth, $cm$')
ax1.set_xlabel('First Sobol index')
ax1.plot(S1_horiz_SOC[:,1], skala_depth)
ax1.plot(S1_horiz_SOC[:,2], skala_depth)
ax1.plot(S1_horiz_SOC[:,3], skala_depth)
ax1.plot(S1_horiz_SOC[:,4], skala_depth)
ax1.plot(S1_horiz_SOC[:,5], skala_depth)
ax1.set_title('$S_i$, SOC')
ax1.get_title()
ax1.invert_yaxis()
# ax1.legend(names_for_legend)
ax1.xaxis.tick_top()

ax2.set_ylabel('Depth, $cm$')
ax2.set_xlabel('First Sobol index')
# ax2.yxticks(xi, for_yaxis_names)
# ax2.set_yticks(range(0,100,10))
# ax2.set_yticklabels([200,40,30], fontsize=12)
ax2.plot(S1_horiz_Clay[:,1], skala_depth)
ax2.plot(S1_horiz_Clay[:,2], skala_depth)
ax2.plot(S1_horiz_Clay[:,3], skala_depth)
ax2.plot(S1_horiz_Clay[:,4], skala_depth)
ax2.plot(S1_horiz_Clay[:,5], skala_depth)
ax2.invert_yaxis()
ax2.set_title('$S_i$, Clay')
ax2.get_title()
# ax2.annotate('Clay', xy=[0.65,125])
ax2.legend(names_for_legend)
ax2.xaxis.tick_top()
ax2.yaxis.tick_right()
plt.savefig('First_sobol_index_for_horisonts.png', dpi=400)

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


labels = [ 'spring-barley', 'soybean', 'sugar-beat-2017']
men_means = [0.213778, 0.018111, 0.000020]
women_means = [0.030127, 0.891079, 0.608782]
# Sand = [0.003310, 0.000928, 0.000031]
# Bulk_density = [0.364043, 0.000406, 0.388077]
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %%
fig, ((ax1, ax2, ax3),(ax4, ax5, ax6)) = plt.subplots(2,3)
ax1.set_ylabel('Depth, $cm$')
ax1.set_xlabel('Sand')
ax1.plot(S1_horiz_Sand[:,1], skala_depth)
ax1.plot(S1_horiz_Sand[:,3], skala_depth)
ax1.plot(S1_horiz_Sand[:,3], skala_depth)
ax1.plot(S1_horiz_Sand[:,4], skala_depth)
ax1.plot(S1_horiz_Sand[:,5], skala_depth)
# ax1.legend(names_for_legend)
ax1.xaxis.tick_top()
ax1.invert_yaxis()
# ax1.xaxis.set_major_formatter(plt.NullFormatter())
# ax1.yaxis.set_major_formatter(plt.NullFormatter())


ax2.set_xlabel('Clay')
ax2.plot(S1_horiz_Clay[:,1], skala_depth)
ax2.plot(S1_horiz_Clay[:,3], skala_depth)
ax2.plot(S1_horiz_Clay[:,3], skala_depth)
ax2.plot(S1_horiz_Clay[:,4], skala_depth)
ax2.plot(S1_horiz_Clay[:,5], skala_depth)
# ax2.legend(names_for_legend)
ax2.xaxis.tick_top()
ax2.invert_yaxis()
# ax2.xaxis.set_major_formatter(plt.NullFormatter())
ax2.yaxis.set_major_formatter(plt.NullFormatter())
ax3.set_xlabel('Bulk Density')
ax3.plot(S1_horiz_Bulk_density[:,1], skala_depth)
ax3.plot(S1_horiz_Bulk_density[:,3], skala_depth)
ax3.plot(S1_horiz_Bulk_density[:,3], skala_depth)
ax3.plot(S1_horiz_Bulk_density[:,4], skala_depth)
ax3.plot(S1_horiz_Bulk_density[:,5], skala_depth)
ax3.set_xlim(0,1)
# ax3.legend(names_for_legend)
ax3.xaxis.tick_top()
ax3.invert_yaxis()
# ax3.xaxis.set_major_formatter(plt.NullFormatter())
ax3.yaxis.set_major_formatter(plt.NullFormatter())
ax4.set_xlabel('C:N ratio')
ax4.set_ylabel('Depth, $cm$')
ax4.plot(S1_horiz_CN[:,1], skala_depth)
ax4.plot(S1_horiz_CN[:,3], skala_depth)
ax4.plot(S1_horiz_CN[:,3], skala_depth)
ax4.plot(S1_horiz_CN[:,4], skala_depth)
ax4.plot(S1_horiz_CN[:,5], skala_depth)
# ax4.legend(names_for_legend)
ax4.xaxis.tick_top()
ax4.invert_yaxis()
ax4.xaxis.set_major_formatter(plt.NullFormatter())
# ax4.yaxis.set_major_formatter(plt.NullFormatter())

ax5.set_xlabel('SOC')
ax5.plot(S1_horiz_SOC[:,1], skala_depth)
ax5.plot(S1_horiz_SOC[:,3], skala_depth)
ax5.plot(S1_horiz_SOC[:,3], skala_depth)
ax5.plot(S1_horiz_SOC[:,4], skala_depth)
ax5.plot(S1_horiz_SOC[:,5], skala_depth)
# ax5.legend(names_for_legend)
ax5.xaxis.set_major_formatter(plt.NullFormatter())
ax5.yaxis.set_major_formatter(plt.NullFormatter())

ax5.xaxis.tick_top()
ax5.invert_yaxis()

ax6.set_xlabel('pH')
ax6.plot(S1_horiz_pH[:,1], skala_depth)
ax6.plot(S1_horiz_pH[:,3], skala_depth)
ax6.plot(S1_horiz_pH[:,3], skala_depth)
ax6.plot(S1_horiz_pH[:,4], skala_depth)
ax6.plot(S1_horiz_pH[:,5], skala_depth)

ax6.xaxis.set_major_formatter(plt.NullFormatter())
ax6.yaxis.set_major_formatter(plt.NullFormatter())


ax6.legend(names_for_legend)
ax6.xaxis.tick_top()
ax6.invert_yaxis()

# fig.set_('Depth, $cm$')
fig.set_figheight(8)
fig.set_figwidth(10)
fig.suptitle('ST index for soil parameters')
# fig.suptitle('Si index for soil parameters', va='center')
fig.suptitle

# fig.legend(names_for_legend, loc='upper right', borderaxespad=0.)
# fig.axes.get_xaxis().set_ticks([])
# fig.axes.get_yaxis().set_ticks([])
# for ax in fig.get_axes():
#     ax.set(xlabel='x-label', ylabel='y-label')
# Out:
# <bound method Figure.suptitle of <Figure size 720x576 with 6 Axes>>
